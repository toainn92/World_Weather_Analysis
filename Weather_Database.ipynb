# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 619

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_desc = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
    
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_desc,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country
                                                 })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | severo-kurilsk
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | salvador
# Processing Record 5 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 1 | mar del plata
# Processing Record 7 of Set 1 | aksarka
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | upernavik
# Processing Record 10 of Set 1 | klaksvik
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | yefimovskiy
# City not found. Skipping...
# Processing Record 13 of Set 1 | brae
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | samfya
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | lorengau
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | cayenne
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | olga
# Processing Record 25 of Set 1 | qeshm
# Processing Record 26 of Set 1 | port blair
# Processing Record 27 of Set 1 | jiaozuo
# Processing Record 28 of Set 1 | thompson
# Processing Record 29 of Set 1 | donskoye
# Processing Record 30 of Set 1 | fortuna
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | naze
# Processing Record 33 of Set 1 | kapaa
# Processing Record 34 of Set 1 | kruisfontein
# Processing Record 35 of Set 1 | leh
# Processing Record 36 of Set 1 | hambantota
# Processing Record 37 of Set 1 | lodja
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | tasiilaq
# Processing Record 41 of Set 1 | sistranda
# Processing Record 42 of Set 1 | cidreira
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | shelburne
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | richards bay
# Processing Record 47 of Set 1 | hasaki
# Processing Record 48 of Set 1 | ondangwa
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | east london
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | canton
# Processing Record 3 of Set 2 | harper
# Processing Record 4 of Set 2 | ust-kuyga
# Processing Record 5 of Set 2 | mafra
# Processing Record 6 of Set 2 | sept-iles
# Processing Record 7 of Set 2 | sukhodol
# Processing Record 8 of Set 2 | airai
# Processing Record 9 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 2 | sitka
# Processing Record 12 of Set 2 | sibiti
# Processing Record 13 of Set 2 | sokol
# Processing Record 14 of Set 2 | gazli
# Processing Record 15 of Set 2 | eureka
# Processing Record 16 of Set 2 | ribeira grande
# Processing Record 17 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 2 | san rafael
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | akdepe
# Processing Record 21 of Set 2 | ketchikan
# Processing Record 22 of Set 2 | yenagoa
# Processing Record 23 of Set 2 | macamic
# Processing Record 24 of Set 2 | sarkand
# Processing Record 25 of Set 2 | qaanaaq
# Processing Record 26 of Set 2 | vao
# Processing Record 27 of Set 2 | alofi
# Processing Record 28 of Set 2 | anadyr
# Processing Record 29 of Set 2 | cabo san lucas
# Processing Record 30 of Set 2 | lianzhou
# Processing Record 31 of Set 2 | chokurdakh
# Processing Record 32 of Set 2 | sovetskiy
# Processing Record 33 of Set 2 | chaman
# Processing Record 34 of Set 2 | portland
# Processing Record 35 of Set 2 | whitecourt
# Processing Record 36 of Set 2 | sao filipe
# Processing Record 37 of Set 2 | esqueda
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | avarua
# Processing Record 40 of Set 2 | mairinque
# Processing Record 41 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 2 | vikindu
# Processing Record 43 of Set 2 | kearney
# Processing Record 44 of Set 2 | kavieng
# Processing Record 45 of Set 2 | paamiut
# Processing Record 46 of Set 2 | dikson
# Processing Record 47 of Set 2 | mattru
# Processing Record 48 of Set 2 | georgetown
# Processing Record 49 of Set 2 | talnakh
# Processing Record 50 of Set 2 | san patricio
# Processing Record 1 of Set 3 | bredasdorp
# Processing Record 2 of Set 3 | huarmey
# Processing Record 3 of Set 3 | ucluelet
# Processing Record 4 of Set 3 | longyearbyen
# Processing Record 5 of Set 3 | bhadrachalam
# Processing Record 6 of Set 3 | riyadh
# Processing Record 7 of Set 3 | vaitape
# Processing Record 8 of Set 3 | bayir
# Processing Record 9 of Set 3 | barabinsk
# Processing Record 10 of Set 3 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 11 of Set 3 | bengkulu
# Processing Record 12 of Set 3 | bilibino
# Processing Record 13 of Set 3 | victoria
# Processing Record 14 of Set 3 | norman wells
# Processing Record 15 of Set 3 | barra do corda
# Processing Record 16 of Set 3 | mahebourg
# Processing Record 17 of Set 3 | abaza
# Processing Record 18 of Set 3 | kangaatsiaq
# Processing Record 19 of Set 3 | kangalassy
# Processing Record 20 of Set 3 | macapa
# Processing Record 21 of Set 3 | souillac
# Processing Record 22 of Set 3 | verkhnyaya inta
# Processing Record 23 of Set 3 | indian head
# Processing Record 24 of Set 3 | khatanga
# Processing Record 25 of Set 3 | castro
# Processing Record 26 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 3 | pangnirtung
# Processing Record 29 of Set 3 | lufilufi
# Processing Record 30 of Set 3 | kaitangata
# Processing Record 31 of Set 3 | winnipeg
# Processing Record 32 of Set 3 | ascension
# Processing Record 33 of Set 3 | lasa
# Processing Record 34 of Set 3 | vawkavysk
# Processing Record 35 of Set 3 | keuruu
# Processing Record 36 of Set 3 | kudat
# Processing Record 37 of Set 3 | bethel
# Processing Record 38 of Set 3 | ponta do sol
# Processing Record 39 of Set 3 | yurimaguas
# Processing Record 40 of Set 3 | puerto madryn
# Processing Record 41 of Set 3 | santa cruz del norte
# Processing Record 42 of Set 3 | dudinka
# Processing Record 43 of Set 3 | kez
# Processing Record 44 of Set 3 | nirmali
# Processing Record 45 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 3 | genhe
# Processing Record 47 of Set 3 | tim
# Processing Record 48 of Set 3 | salinopolis
# Processing Record 49 of Set 3 | leningradskiy
# Processing Record 50 of Set 3 | vardo
# Processing Record 1 of Set 4 | chinsali
# Processing Record 2 of Set 4 | kaisiadorys
# Processing Record 3 of Set 4 | barrow
# Processing Record 4 of Set 4 | puerto ayora
# Processing Record 5 of Set 4 | lishan
# Processing Record 6 of Set 4 | mizdah
# Processing Record 7 of Set 4 | sao raimundo das mangabeiras
# Processing Record 8 of Set 4 | shingu
# Processing Record 9 of Set 4 | comodoro rivadavia
# Processing Record 10 of Set 4 | nyurba
# Processing Record 11 of Set 4 | waingapu
# Processing Record 12 of Set 4 | san quintin
# Processing Record 13 of Set 4 | qui nhon
# Processing Record 14 of Set 4 | muros
# Processing Record 15 of Set 4 | port augusta
# Processing Record 16 of Set 4 | esperance
# Processing Record 17 of Set 4 | port alfred
# Processing Record 18 of Set 4 | tiksi
# Processing Record 19 of Set 4 | urucui
# Processing Record 20 of Set 4 | osorno
# Processing Record 21 of Set 4 | grindavik
# Processing Record 22 of Set 4 | ixtapa
# Processing Record 23 of Set 4 | ossora
# Processing Record 24 of Set 4 | saint george
# Processing Record 25 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 26 of Set 4 | mitu
# Processing Record 27 of Set 4 | nome
# Processing Record 28 of Set 4 | varna
# Processing Record 29 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 4 | bozoum
# Processing Record 31 of Set 4 | kodiak
# Processing Record 32 of Set 4 | ca mau
# Processing Record 33 of Set 4 | kaduy
# Processing Record 34 of Set 4 | ostrovnoy
# Processing Record 35 of Set 4 | porto novo
# Processing Record 36 of Set 4 | copiapo
# Processing Record 37 of Set 4 | lavrentiya
# Processing Record 38 of Set 4 | andenes
# Processing Record 39 of Set 4 | targoviste
# Processing Record 40 of Set 4 | arman
# Processing Record 41 of Set 4 | bundaberg
# Processing Record 42 of Set 4 | smithers
# Processing Record 43 of Set 4 | falam
# Processing Record 44 of Set 4 | narsaq
# Processing Record 45 of Set 4 | ati
# Processing Record 46 of Set 4 | gravdal
# Processing Record 47 of Set 4 | verkhoyansk
# Processing Record 48 of Set 4 | roebourne
# Processing Record 49 of Set 4 | isangel
# Processing Record 50 of Set 4 | chuy
# Processing Record 1 of Set 5 | tombouctou
# Processing Record 2 of Set 5 | port hedland
# Processing Record 3 of Set 5 | sur
# Processing Record 4 of Set 5 | villa carlos paz
# Processing Record 5 of Set 5 | brewster
# Processing Record 6 of Set 5 | te anau
# Processing Record 7 of Set 5 | asau
# Processing Record 8 of Set 5 | papetoai
# Processing Record 9 of Set 5 | kununurra
# Processing Record 10 of Set 5 | avera
# Processing Record 11 of Set 5 | abha
# Processing Record 12 of Set 5 | codrington
# Processing Record 13 of Set 5 | saldanha
# Processing Record 14 of Set 5 | mount gambier
# Processing Record 15 of Set 5 | batagay
# Processing Record 16 of Set 5 | pedasi
# Processing Record 17 of Set 5 | diamond harbour
# Processing Record 18 of Set 5 | borzya
# Processing Record 19 of Set 5 | tuatapere
# Processing Record 20 of Set 5 | sola
# Processing Record 21 of Set 5 | luderitz
# Processing Record 22 of Set 5 | mikhaylovka
# Processing Record 23 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 5 | salalah
# Processing Record 25 of Set 5 | alcudia
# Processing Record 26 of Set 5 | lagoa
# Processing Record 27 of Set 5 | kutum
# Processing Record 28 of Set 5 | dumai
# Processing Record 29 of Set 5 | college
# Processing Record 30 of Set 5 | berlevag
# Processing Record 31 of Set 5 | catalina
# Processing Record 32 of Set 5 | banda aceh
# Processing Record 33 of Set 5 | bambous virieux
# Processing Record 34 of Set 5 | erechim
# Processing Record 35 of Set 5 | santiago de cao
# Processing Record 36 of Set 5 | zhigansk
# Processing Record 37 of Set 5 | panaba
# Processing Record 38 of Set 5 | nichinan
# Processing Record 39 of Set 5 | kitgum
# Processing Record 40 of Set 5 | carnarvon
# Processing Record 41 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 43 of Set 5 | vathi
# Processing Record 44 of Set 5 | yunjinghong
# City not found. Skipping...
# Processing Record 45 of Set 5 | iqaluit
# Processing Record 46 of Set 5 | la ronge
# Processing Record 47 of Set 5 | ancud
# Processing Record 48 of Set 5 | yar-sale
# Processing Record 49 of Set 5 | kaduna
# Processing Record 50 of Set 5 | camacha
# Processing Record 1 of Set 6 | buchanan
# Processing Record 2 of Set 6 | mezhdurechensk
# Processing Record 3 of Set 6 | mortka
# Processing Record 4 of Set 6 | port elizabeth
# Processing Record 5 of Set 6 | mayya
# Processing Record 6 of Set 6 | cap-aux-meules
# Processing Record 7 of Set 6 | katsiveli
# City not found. Skipping...
# Processing Record 8 of Set 6 | vanimo
# Processing Record 9 of Set 6 | egvekinot
# Processing Record 10 of Set 6 | domoni
# Processing Record 11 of Set 6 | udachnyy
# Processing Record 12 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 6 | coihaique
# Processing Record 14 of Set 6 | santiago del estero
# Processing Record 15 of Set 6 | ballina
# Processing Record 16 of Set 6 | minnedosa
# Processing Record 17 of Set 6 | atagay
# Processing Record 18 of Set 6 | togur
# Processing Record 19 of Set 6 | nanning
# Processing Record 20 of Set 6 | mount isa
# Processing Record 21 of Set 6 | srednekolymsk
# Processing Record 22 of Set 6 | cairns
# Processing Record 23 of Set 6 | san carlos de bariloche
# Processing Record 24 of Set 6 | atbasar
# Processing Record 25 of Set 6 | ahipara
# Processing Record 26 of Set 6 | kahului
# Processing Record 27 of Set 6 | plettenberg bay
# Processing Record 28 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 6 | danville
# Processing Record 30 of Set 6 | ugoofaaru
# Processing Record 31 of Set 6 | torbay
# Processing Record 32 of Set 6 | tavda
# Processing Record 33 of Set 6 | dauphin
# Processing Record 34 of Set 6 | turukhansk
# Processing Record 35 of Set 6 | palana
# Processing Record 36 of Set 6 | port macquarie
# Processing Record 37 of Set 6 | playas
# Processing Record 38 of Set 6 | bambanglipuro
# Processing Record 39 of Set 6 | rosarito
# Processing Record 40 of Set 6 | lusambo
# Processing Record 41 of Set 6 | praia da vitoria
# Processing Record 42 of Set 6 | neon karlovasion
# Processing Record 43 of Set 6 | leshukonskoye
# Processing Record 44 of Set 6 | banjar
# Processing Record 45 of Set 6 | takaka
# Processing Record 46 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 47 of Set 6 | karachi
# Processing Record 48 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 49 of Set 6 | kayes
# Processing Record 50 of Set 6 | floro
# Processing Record 1 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 7 | san luis
# Processing Record 4 of Set 7 | saskylakh
# Processing Record 5 of Set 7 | winona
# Processing Record 6 of Set 7 | labrea
# Processing Record 7 of Set 7 | point fortin
# Processing Record 8 of Set 7 | valdivia
# Processing Record 9 of Set 7 | saiha
# Processing Record 10 of Set 7 | sulangan
# Processing Record 11 of Set 7 | trairi
# Processing Record 12 of Set 7 | tabas
# Processing Record 13 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 14 of Set 7 | george
# Processing Record 15 of Set 7 | hua hin
# Processing Record 16 of Set 7 | mandalgovi
# Processing Record 17 of Set 7 | ust-tsilma
# Processing Record 18 of Set 7 | beringovskiy
# Processing Record 19 of Set 7 | redlands
# Processing Record 20 of Set 7 | saint-philippe
# Processing Record 21 of Set 7 | tuktoyaktuk
# Processing Record 22 of Set 7 | ubinskoye
# Processing Record 23 of Set 7 | tual
# Processing Record 24 of Set 7 | aksarayskiy
# Processing Record 25 of Set 7 | porangatu
# Processing Record 26 of Set 7 | ereymentau
# Processing Record 27 of Set 7 | arroyos y esteros
# Processing Record 28 of Set 7 | nguru
# Processing Record 29 of Set 7 | durango
# Processing Record 30 of Set 7 | sao francisco
# Processing Record 31 of Set 7 | kautokeino
# Processing Record 32 of Set 7 | aberdeen
# Processing Record 33 of Set 7 | havelock
# Processing Record 34 of Set 7 | bandarbeyla
# Processing Record 35 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 7 | birao
# Processing Record 37 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 38 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 7 | ukiah
# Processing Record 40 of Set 7 | makakilo city
# Processing Record 41 of Set 7 | nelson bay
# Processing Record 42 of Set 7 | abu samrah
# Processing Record 43 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 7 | road town
# Processing Record 45 of Set 7 | mareeba
# Processing Record 46 of Set 7 | islamkot
# Processing Record 47 of Set 7 | arraial do cabo
# Processing Record 48 of Set 7 | nanortalik
# Processing Record 49 of Set 7 | shiraz
# Processing Record 50 of Set 7 | kodinsk
# Processing Record 1 of Set 8 | tshela
# Processing Record 2 of Set 8 | san policarpo
# Processing Record 3 of Set 8 | manggar
# Processing Record 4 of Set 8 | waipawa
# Processing Record 5 of Set 8 | pokhara
# Processing Record 6 of Set 8 | eastleigh
# Processing Record 7 of Set 8 | atar
# Processing Record 8 of Set 8 | angra dos reis
# Processing Record 9 of Set 8 | ayan
# Processing Record 10 of Set 8 | sinazongwe
# Processing Record 11 of Set 8 | taoudenni
# Processing Record 12 of Set 8 | mangrol
# Processing Record 13 of Set 8 | gdov
# Processing Record 14 of Set 8 | olafsvik
# Processing Record 15 of Set 8 | roxana
# Processing Record 16 of Set 8 | palmer
# Processing Record 17 of Set 8 | gat
# Processing Record 18 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 8 | medicine hat
# Processing Record 20 of Set 8 | ilulissat
# Processing Record 21 of Set 8 | ende
# Processing Record 22 of Set 8 | ron phibun
# Processing Record 23 of Set 8 | djibo
# Processing Record 24 of Set 8 | vila velha
# Processing Record 25 of Set 8 | whitehorse
# Processing Record 26 of Set 8 | papillion
# Processing Record 27 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 28 of Set 8 | dingle
# Processing Record 29 of Set 8 | lata
# Processing Record 30 of Set 8 | gharo
# Processing Record 31 of Set 8 | yeppoon
# Processing Record 32 of Set 8 | providencia
# Processing Record 33 of Set 8 | baykit
# Processing Record 34 of Set 8 | opuwo
# Processing Record 35 of Set 8 | yerbogachen
# Processing Record 36 of Set 8 | constitucion
# Processing Record 37 of Set 8 | poltavka
# Processing Record 38 of Set 8 | hami
# Processing Record 39 of Set 8 | uberaba
# Processing Record 40 of Set 8 | havre-saint-pierre
# Processing Record 41 of Set 8 | vostok
# Processing Record 42 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 8 | katsuura
# Processing Record 44 of Set 8 | katobu
# Processing Record 45 of Set 8 | provideniya
# Processing Record 46 of Set 8 | port lincoln
# Processing Record 47 of Set 8 | axim
# Processing Record 48 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 8 | saint-marc
# Processing Record 50 of Set 8 | sinnamary
# Processing Record 1 of Set 9 | cabedelo
# Processing Record 2 of Set 9 | hamilton
# Processing Record 3 of Set 9 | ouallam
# Processing Record 4 of Set 9 | carauari
# Processing Record 5 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 9 | ternate
# Processing Record 7 of Set 9 | oktyabrskoye
# Processing Record 8 of Set 9 | tahoua
# Processing Record 9 of Set 9 | half moon bay
# Processing Record 10 of Set 9 | tura
# Processing Record 11 of Set 9 | el wasta
# City not found. Skipping...
# Processing Record 12 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 13 of Set 9 | safaga
# Processing Record 14 of Set 9 | governador valadares
# Processing Record 15 of Set 9 | cherskiy
# Processing Record 16 of Set 9 | kerman
# Processing Record 17 of Set 9 | okhtyrka
# Processing Record 18 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 9 | nurota
# Processing Record 20 of Set 9 | kalmunai
# Processing Record 21 of Set 9 | polyarnyy
# Processing Record 22 of Set 9 | zasheyek
# Processing Record 23 of Set 9 | clyde river
# Processing Record 24 of Set 9 | bria
# Processing Record 25 of Set 9 | pavda
# City not found. Skipping...
# Processing Record 26 of Set 9 | nara
# Processing Record 27 of Set 9 | havoysund
# Processing Record 28 of Set 9 | karla
# Processing Record 29 of Set 9 | monrovia
# Processing Record 30 of Set 9 | sabha
# Processing Record 31 of Set 9 | simbahan
# Processing Record 32 of Set 9 | tezu
# Processing Record 33 of Set 9 | yingcheng
# Processing Record 34 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 35 of Set 9 | johnstown
# Processing Record 36 of Set 9 | fare
# Processing Record 37 of Set 9 | balsas
# Processing Record 38 of Set 9 | najran
# Processing Record 39 of Set 9 | santa cruz de la palma
# Processing Record 40 of Set 9 | kloulklubed
# Processing Record 41 of Set 9 | fort nelson
# Processing Record 42 of Set 9 | jumla
# Processing Record 43 of Set 9 | camrose
# Processing Record 44 of Set 9 | solwezi
# Processing Record 45 of Set 9 | pisco
# Processing Record 46 of Set 9 | pouebo
# Processing Record 47 of Set 9 | iki-burul
# Processing Record 48 of Set 9 | mulege
# Processing Record 49 of Set 9 | baghdad
# Processing Record 50 of Set 9 | ulladulla
# Processing Record 1 of Set 10 | sao jose da coroa grande
# Processing Record 2 of Set 10 | do rud
# City not found. Skipping...
# Processing Record 3 of Set 10 | cseteny
# Processing Record 4 of Set 10 | oistins
# Processing Record 5 of Set 10 | moldovita
# Processing Record 6 of Set 10 | amahai
# Processing Record 7 of Set 10 | biltine
# Processing Record 8 of Set 10 | pevek
# Processing Record 9 of Set 10 | walvis bay
# Processing Record 10 of Set 10 | miami
# Processing Record 11 of Set 10 | westport
# Processing Record 12 of Set 10 | san cristobal
# Processing Record 13 of Set 10 | bembereke
# Processing Record 14 of Set 10 | manzil tamim
# City not found. Skipping...
# Processing Record 15 of Set 10 | windhoek
# Processing Record 16 of Set 10 | svetlogorsk
# Processing Record 17 of Set 10 | antofagasta
# Processing Record 18 of Set 10 | komsomolskoye
# Processing Record 19 of Set 10 | zajecar
# Processing Record 20 of Set 10 | basco
# Processing Record 21 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 22 of Set 10 | brignoles
# Processing Record 23 of Set 10 | kuah
# Processing Record 24 of Set 10 | bemidji
# Processing Record 25 of Set 10 | gueret
# Processing Record 26 of Set 10 | saint-pierre
# Processing Record 27 of Set 10 | nigde
# Processing Record 28 of Set 10 | la mira
# Processing Record 29 of Set 10 | morehead
# Processing Record 30 of Set 10 | roma
# Processing Record 31 of Set 10 | dipkarpaz
# City not found. Skipping...
# Processing Record 32 of Set 10 | zhaotong
# Processing Record 33 of Set 10 | cap malheureux
# Processing Record 34 of Set 10 | uruzgan
# Processing Record 35 of Set 10 | severna park
# Processing Record 36 of Set 10 | kananga
# Processing Record 37 of Set 10 | brigantine
# Processing Record 38 of Set 10 | yamethin
# Processing Record 39 of Set 10 | sokolo
# Processing Record 40 of Set 10 | tamuin
# Processing Record 41 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 10 | malgrat de mar
# Processing Record 43 of Set 10 | byron bay
# Processing Record 44 of Set 10 | atambua
# Processing Record 45 of Set 10 | zaysan
# Processing Record 46 of Set 10 | kiunga
# Processing Record 47 of Set 10 | mahibadhoo
# Processing Record 48 of Set 10 | kottagudem
# Processing Record 49 of Set 10 | denpasar
# Processing Record 50 of Set 10 | guymon
# Processing Record 1 of Set 11 | inongo
# Processing Record 2 of Set 11 | port hardy
# Processing Record 3 of Set 11 | eyl
# Processing Record 4 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 5 of Set 11 | faanui
# Processing Record 6 of Set 11 | saint anthony
# Processing Record 7 of Set 11 | guerrero negro
# Processing Record 8 of Set 11 | korla
# Processing Record 9 of Set 11 | yatou
# Processing Record 10 of Set 11 | atherton
# Processing Record 11 of Set 11 | abilene
# Processing Record 12 of Set 11 | stamsund
# City not found. Skipping...
# Processing Record 13 of Set 11 | itarema
# Processing Record 14 of Set 11 | krasnopavlivka
# Processing Record 15 of Set 11 | black diamond
# Processing Record 16 of Set 11 | fairbanks
# Processing Record 17 of Set 11 | veraval
# Processing Record 18 of Set 11 | bhadra
# Processing Record 19 of Set 11 | nantucket
# Processing Record 20 of Set 11 | pulsano
# Processing Record 21 of Set 11 | taga
# Processing Record 22 of Set 11 | kaeo
# Processing Record 23 of Set 11 | faya
# Processing Record 24 of Set 11 | paris
# Processing Record 25 of Set 11 | winnemucca
# Processing Record 26 of Set 11 | eaglesham
# Processing Record 27 of Set 11 | isla vista
# Processing Record 28 of Set 11 | parral
# Processing Record 29 of Set 11 | sumbe
# Processing Record 30 of Set 11 | nemuro
# Processing Record 31 of Set 11 | turka
# Processing Record 32 of Set 11 | sungaipenuh
# Processing Record 33 of Set 11 | beloha
# Processing Record 34 of Set 11 | mutis
# Processing Record 35 of Set 11 | champerico
# Processing Record 36 of Set 11 | moose factory
# Processing Record 37 of Set 11 | yangjiang
# Processing Record 38 of Set 11 | oranjestad
# Processing Record 39 of Set 11 | jian
# Processing Record 40 of Set 11 | esso
# Processing Record 41 of Set 11 | nabire
# Processing Record 42 of Set 11 | burica
# City not found. Skipping...
# Processing Record 43 of Set 11 | puerto carreno
# Processing Record 44 of Set 11 | prince rupert
# Processing Record 45 of Set 11 | micheweni
# Processing Record 46 of Set 11 | oksfjord
# Processing Record 47 of Set 11 | hay river
# Processing Record 48 of Set 11 | shimanovsk
# Processing Record 49 of Set 11 | bang saphan
# Processing Record 50 of Set 11 | stornoway
# Processing Record 1 of Set 12 | kupino
# Processing Record 2 of Set 12 | abiy adi
# City not found. Skipping...
# Processing Record 3 of Set 12 | takestan
# Processing Record 4 of Set 12 | devils lake
# Processing Record 5 of Set 12 | panshi
# Processing Record 6 of Set 12 | jiaocheng
# Processing Record 7 of Set 12 | tomatlan
# Processing Record 8 of Set 12 | bhawanipatna
# Processing Record 9 of Set 12 | beeville
# Processing Record 10 of Set 12 | juifang
# City not found. Skipping...
# Processing Record 11 of Set 12 | gushikawa
# Processing Record 12 of Set 12 | lewistown
# Processing Record 13 of Set 12 | meulaboh
# Processing Record 14 of Set 12 | zhanaozen
# Processing Record 15 of Set 12 | petatlan
# Processing Record 16 of Set 12 | batticaloa
# Processing Record 17 of Set 12 | sibolga
# Processing Record 18 of Set 12 | huayucachi
# Processing Record 19 of Set 12 | holme
# Processing Record 20 of Set 12 | shebunino
# Processing Record 21 of Set 12 | mgachi
# Processing Record 22 of Set 12 | charlestown
# Processing Record 23 of Set 12 | cravo norte
# Processing Record 24 of Set 12 | kozhevnikovo
# Processing Record 25 of Set 12 | mahanje
# Processing Record 26 of Set 12 | svetlaya
# Processing Record 27 of Set 12 | channel-port aux basques
# Processing Record 28 of Set 12 | campo verde
# Processing Record 29 of Set 12 | suicheng
# Processing Record 30 of Set 12 | barreiros
# Processing Record 31 of Set 12 | garowe
# Processing Record 32 of Set 12 | santo domingo
# Processing Record 33 of Set 12 | mackay
# Processing Record 34 of Set 12 | ankang
# Processing Record 35 of Set 12 | nouakchott
# Processing Record 36 of Set 12 | villamontes
# Processing Record 37 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 12 | springfield
# Processing Record 39 of Set 12 | jawhar
# Processing Record 40 of Set 12 | kirakira
# Processing Record 41 of Set 12 | hokitika
# Processing Record 42 of Set 12 | podosinovets
# Processing Record 43 of Set 12 | halifax
# Processing Record 44 of Set 12 | safakulevo
# Processing Record 45 of Set 12 | itoman
# Processing Record 46 of Set 12 | laguna
# Processing Record 47 of Set 12 | poum
# Processing Record 48 of Set 12 | leo
# Processing Record 49 of Set 12 | bronnoysund
# Processing Record 50 of Set 12 | azare
# Processing Record 1 of Set 13 | kamenka
# Processing Record 2 of Set 13 | umm kaddadah
# Processing Record 3 of Set 13 | estelle
# Processing Record 4 of Set 13 | saint combs
# City not found. Skipping...
# Processing Record 5 of Set 13 | mubende
# Processing Record 6 of Set 13 | pontarlier
# Processing Record 7 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 8 of Set 13 | vestmannaeyjar
# Processing Record 9 of Set 13 | trelleborg
# Processing Record 10 of Set 13 | chak
# Processing Record 11 of Set 13 | coxim
# Processing Record 12 of Set 13 | chandla
# Processing Record 13 of Set 13 | labuhan
# Processing Record 14 of Set 13 | virginia beach
# Processing Record 15 of Set 13 | hofn
# Processing Record 16 of Set 13 | tiznit
# Processing Record 17 of Set 13 | ishigaki
# Processing Record 18 of Set 13 | mana
# Processing Record 19 of Set 13 | batamshinskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng Current Description  Max Temp  Humidity  \
# 0    Punta Arenas -53.15  -70.92       broken clouds     42.80        87
# 1  Severo-Kurilsk  50.68  156.12       moderate rain     40.42        91
# 2       Cape Town -33.93   18.42           clear sky     57.00        62
# 3        Salvador  13.83  -88.92       broken clouds     80.60        69
# 4   Mar Del Plata -38.00  -57.56           clear sky     51.01        93
# 5         Aksarka  66.56   67.80     overcast clouds     34.74        98
# 6         Rikitea -23.12 -134.97           clear sky     76.01        67
# 7       Upernavik  72.79  -56.15     overcast clouds     19.38        96
# 8        Klaksvik  62.23   -6.59    scattered clouds     46.40        87
# 9     Yellowknife  62.46 -114.35       broken clouds     12.99        92
#
#    Cloudiness  Wind Speed Country
# 0          75        6.93      CL
# 1         100       38.27      RU
# 2           0       18.34      ZA
# 3          75        5.82      SV
# 4           0        6.93      AR
# 5         100       13.18      RU
# 6           0        4.00      PF
# 7          96        2.68      GL
# 8          27       17.22      FO
# 9          75        8.05      CA

# %%
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity","Cloudiness","Wind Speed","Current Description"]
new_column_order
# Out:
# ['City',
#  'Country',
#  'Lat',
#  'Lng',
#  'Max Temp',
#  'Humidity',
#  'Cloudiness',
#  'Wind Speed',
#  'Current Description']

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Punta Arenas      CL -53.15  -70.92     42.80        87          75
# 1  Severo-Kurilsk      RU  50.68  156.12     40.42        91         100
# 2       Cape Town      ZA -33.93   18.42     57.00        62           0
# 3        Salvador      SV  13.83  -88.92     80.60        69          75
# 4   Mar Del Plata      AR -38.00  -57.56     51.01        93           0
# 5         Aksarka      RU  66.56   67.80     34.74        98         100
# 6         Rikitea      PF -23.12 -134.97     76.01        67           0
# 7       Upernavik      GL  72.79  -56.15     19.38        96          96
# 8        Klaksvik      FO  62.23   -6.59     46.40        87          27
# 9     Yellowknife      CA  62.46 -114.35     12.99        92          75
#
#    Wind Speed Current Description
# 0        6.93       broken clouds
# 1       38.27       moderate rain
# 2       18.34           clear sky
# 3        5.82       broken clouds
# 4        6.93           clear sky
# 5       13.18     overcast clouds
# 6        4.00           clear sky
# 7        2.68     overcast clouds
# 8       17.22    scattered clouds
# 9        8.05       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
